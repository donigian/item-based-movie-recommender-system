# %% [markdown]
# # Item-Based Collaborative Filtering for Movies

# %%
# !head -n5 movies.csv
# Out:
# 1,Toy Story (1995),Adventure|Animation|Children|Comedy|Fantasy
# 2,Jumanji (1995),Adventure|Children|Fantasy
# 3,Grumpier Old Men (1995),Comedy|Romance
# 4,Waiting to Exhale (1995),Comedy|Drama|Romance
# 5,Father of the Bride Part II (1995),Comedy

# %%
# !head -n5 ratings_5M.csv
# Out:
# 1,2,3.5,1112486027
# 1,29,3.5,1112484676
# 1,32,3.5,1112484819
# 1,47,3.5,1112484727
# 1,50,3.5,1112484580

# %%
# !wc -l ml-latest-small/movies.csv
# !wc -l ml-latest-small/ratings.csv
# Out:
#     9126 ml-latest-small/movies.csv
#   100005 ml-latest-small/ratings.csv

# %% [markdown]
# Start by importing the MovieLens 20M data set into a pandas DataFrame:

# %%
import pandas as pd

r_cols = ['user_id', 'movie_id', 'rating']
ratings = pd.read_csv('ratings_500K.csv', 
                      names=r_cols, 
                      usecols=range(3), 
                      header=None, 
                      low_memory=False, 
                      dtype={'user_id':'int', 
                             'movie_id':'int',
                             'rating':'float'})
ratings.head()
# Out:
#    user_id  movie_id  rating
# 0        1         2     3.5
# 1        1        29     3.5
# 2        1        32     3.5
# 3        1        47     3.5
# 4        1        50     3.5

# %%
m_cols = ['movie_id', 'title']
movies = pd.read_csv('movies.csv', 
                     names=m_cols, 
                     usecols=range(2), 
                     header=None, 
                     low_memory=False, 
                     dtype={'movie_id':'int',
                            'user_id':'int'})

movies.head()
# Out:
#    movie_id                               title
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)

# %%
ratings = pd.merge(movies, ratings)

ratings.head()
# Out:
#    movie_id             title  user_id  rating
# 0         1  Toy Story (1995)        3     4.0
# 1         1  Toy Story (1995)        6     5.0
# 2         1  Toy Story (1995)        8     4.0
# 3         1  Toy Story (1995)       10     4.0
# 4         1  Toy Story (1995)       11     4.5

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 0 to 499999
# Data columns (total 4 columns):
# movie_id    500000 non-null int64
# title       500000 non-null object
# user_id     500000 non-null int64
# rating      500000 non-null float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 19.1+ MB

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 2 columns):
# movie_id    27278 non-null int64
# title       27278 non-null object
# dtypes: int64(1), object(1)
# memory usage: 426.3+ KB

# %% [markdown]
# Create a pivot table of users & the movies they rated.
#
# NaN indicates missing data or movies that a given user hasn't watched

# %%
userRatings = ratings.pivot_table(index=['user_id'],columns=['title'],values='rating')
userRatings.head()
# Out:
# title    "Great Performances" Cats (1998)  $5 a Day (2008)  \
# user_id
# 1                                     NaN              NaN
# 2                                     NaN              NaN
# 3                                     NaN              NaN
# 4                                     NaN              NaN
# 5                                     NaN              NaN
#
# title    'Hellboy': The Seeds of Creation (2004)  \
# user_id
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
#
# title    'Neath the Arizona Skies (1934)  'Round Midnight (1986)  \
# user_id
# 1                                    NaN                     NaN
# 2                                    NaN                     NaN
# 3                                    NaN                     NaN
# 4                                    NaN                     NaN
# 5                                    NaN                     NaN
#
# title    'Salem's Lot (2004)  'Til There Was You (1997)  'burbs, The (1989)  \
# user_id
# 1                        NaN                        NaN                 NaN
# 2                        NaN                        NaN                 NaN
# 3                        NaN                        NaN                 NaN
# 4                        NaN                        NaN                 NaN
# 5                        NaN                        NaN                 NaN
#
# title    'night Mother (1986)  (500) Days of Summer (2009)  \
# user_id
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# 5                         NaN                          NaN
#
# title                      ...                      Zulu Dawn (1979)  \
# user_id                    ...
# 1                          ...                                   NaN
# 2                          ...                                   NaN
# 3                          ...                                   NaN
# 4                          ...                                   NaN
# 5                          ...                                   NaN
#
# title    Zus & Zo (2001)  [REC] (2007)  [REC]² (2009)  eXistenZ (1999)  \
# user_id
# 1                    NaN           NaN            NaN              NaN
# 2                    NaN           NaN            NaN              NaN
# 3                    NaN           NaN            NaN              NaN
# 4                    NaN           NaN            NaN              NaN
# 5                    NaN           NaN            NaN              NaN
#
# title    loudQUIETloud: A Film About the Pixies (2006)  xXx (2002)  \
# user_id
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# 5                                                  NaN         NaN
#
# title    xXx: State of the Union (2005)  ¡Three Amigos! (1986)  \
# user_id
# 1                                   NaN                    NaN
# 2                                   NaN                    NaN
# 3                                   NaN                    NaN
# 4                                   NaN                    NaN
# 5                                   NaN                    NaN
#
# title    À nous la liberté (Freedom for Us) (1931)
# user_id
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
#
# [5 rows x 12272 columns]

# %% [markdown]
# **corr()** method computes a correlation score for every column pair in the matrix
#
# This results in a correlation score between every pair of movies (at least one user rated both movies - otherwise NaN's)

# %%
corrMatrix = userRatings.corr()
corrMatrix.head()

# %% [markdown]
# Use **min_periods** instead to restrict our results to movies that lots of people have rated. As a result, only popular movies (more ratings by users) will be more recognizable. Otherwise, you'll see a whole bunch of movies which only a few people have rated.
#
# Throw out movies if less than 100 people have rated it.

# %%
corrMatrix = userRatings.corr(method='pearson', min_periods=100)
corrMatrix.head()
# Out:
# title                                    "Great Performances" Cats (1998)  \
# title
# "Great Performances" Cats (1998)                                      NaN
# $5 a Day (2008)                                                       NaN
# 'Hellboy': The Seeds of Creation (2004)                               NaN
# 'Neath the Arizona Skies (1934)                                       NaN
# 'Round Midnight (1986)                                                NaN
#
# title                                    $5 a Day (2008)  \
# title
# "Great Performances" Cats (1998)                     NaN
# $5 a Day (2008)                                      NaN
# 'Hellboy': The Seeds of Creation (2004)              NaN
# 'Neath the Arizona Skies (1934)                      NaN
# 'Round Midnight (1986)                               NaN
#
# title                                    'Hellboy': The Seeds of Creation (2004)  \
# title
# "Great Performances" Cats (1998)                                             NaN
# $5 a Day (2008)                                                              NaN
# 'Hellboy': The Seeds of Creation (2004)                                      NaN
# 'Neath the Arizona Skies (1934)                                              NaN
# 'Round Midnight (1986)                                                       NaN
#
# title                                    'Neath the Arizona Skies (1934)  \
# title
# "Great Performances" Cats (1998)                                     NaN
# $5 a Day (2008)                                                      NaN
# 'Hellboy': The Seeds of Creation (2004)                              NaN
# 'Neath the Arizona Skies (1934)                                      NaN
# 'Round Midnight (1986)                                               NaN
#
# title                                    'Round Midnight (1986)  \
# title
# "Great Performances" Cats (1998)                            NaN
# $5 a Day (2008)                                             NaN
# 'Hellboy': The Seeds of Creation (2004)                     NaN
# 'Neath the Arizona Skies (1934)                             NaN
# 'Round Midnight (1986)                                      NaN
#
# title                                    'Salem's Lot (2004)  \
# title
# "Great Performances" Cats (1998)                         NaN
# $5 a Day (2008)                                          NaN
# 'Hellboy': The Seeds of Creation (2004)                  NaN
# 'Neath the Arizona Skies (1934)                          NaN
# 'Round Midnight (1986)                                   NaN
#
# title                                    'Til There Was You (1997)  \
# title
# "Great Performances" Cats (1998)                               NaN
# $5 a Day (2008)                                                NaN
# 'Hellboy': The Seeds of Creation (2004)                        NaN
# 'Neath the Arizona Skies (1934)                                NaN
# 'Round Midnight (1986)                                         NaN
#
# title                                    'burbs, The (1989)  \
# title
# "Great Performances" Cats (1998)                        NaN
# $5 a Day (2008)                                         NaN
# 'Hellboy': The Seeds of Creation (2004)                 NaN
# 'Neath the Arizona Skies (1934)                         NaN
# 'Round Midnight (1986)                                  NaN
#
# title                                    'night Mother (1986)  \
# title
# "Great Performances" Cats (1998)                          NaN
# $5 a Day (2008)                                           NaN
# 'Hellboy': The Seeds of Creation (2004)                   NaN
# 'Neath the Arizona Skies (1934)                           NaN
# 'Round Midnight (1986)                                    NaN
#
# title                                    (500) Days of Summer (2009)  \
# title
# "Great Performances" Cats (1998)                                 NaN
# $5 a Day (2008)                                                  NaN
# 'Hellboy': The Seeds of Creation (2004)                          NaN
# 'Neath the Arizona Skies (1934)                                  NaN
# 'Round Midnight (1986)                                           NaN
#
# title                                                      ...                      \
# title                                                      ...
# "Great Performances" Cats (1998)                           ...
# $5 a Day (2008)                                            ...
# 'Hellboy': The Seeds of Creation (2004)                    ...
# 'Neath the Arizona Skies (1934)                            ...
# 'Round Midnight (1986)                                     ...
#
# title                                    Zulu Dawn (1979)  Zus & Zo (2001)  \
# title
# "Great Performances" Cats (1998)                      NaN              NaN
# $5 a Day (2008)                                       NaN              NaN
# 'Hellboy': The Seeds of Creation (2004)               NaN              NaN
# 'Neath the Arizona Skies (1934)                       NaN              NaN
# 'Round Midnight (1986)                                NaN              NaN
#
# title                                    [REC] (2007)  [REC]² (2009)  \
# title
# "Great Performances" Cats (1998)                  NaN            NaN
# $5 a Day (2008)                                   NaN            NaN
# 'Hellboy': The Seeds of Creation (2004)           NaN            NaN
# 'Neath the Arizona Skies (1934)                   NaN            NaN
# 'Round Midnight (1986)                            NaN            NaN
#
# title                                    eXistenZ (1999)  \
# title
# "Great Performances" Cats (1998)                     NaN
# $5 a Day (2008)                                      NaN
# 'Hellboy': The Seeds of Creation (2004)              NaN
# 'Neath the Arizona Skies (1934)                      NaN
# 'Round Midnight (1986)                               NaN
#
# title                                    loudQUIETloud: A Film About the Pixies (2006)  \
# title
# "Great Performances" Cats (1998)                                                   NaN
# $5 a Day (2008)                                                                    NaN
# 'Hellboy': The Seeds of Creation (2004)                                            NaN
# 'Neath the Arizona Skies (1934)                                                    NaN
# 'Round Midnight (1986)                                                             NaN
#
# title                                    xXx (2002)  \
# title
# "Great Performances" Cats (1998)                NaN
# $5 a Day (2008)                                 NaN
# 'Hellboy': The Seeds of Creation (2004)         NaN
# 'Neath the Arizona Skies (1934)                 NaN
# 'Round Midnight (1986)                          NaN
#
# title                                    xXx: State of the Union (2005)  \
# title
# "Great Performances" Cats (1998)                                    NaN
# $5 a Day (2008)                                                     NaN
# 'Hellboy': The Seeds of Creation (2004)                             NaN
# 'Neath the Arizona Skies (1934)                                     NaN
# 'Round Midnight (1986)                                              NaN
#
# title                                    ¡Three Amigos! (1986)  \
# title
# "Great Performances" Cats (1998)                           NaN
# $5 a Day (2008)                                            NaN
# 'Hellboy': The Seeds of Creation (2004)                    NaN
# 'Neath the Arizona Skies (1934)                            NaN
# 'Round Midnight (1986)                                     NaN
#
# title                                    À nous la liberté (Freedom for Us) (1931)
# title
# "Great Performances" Cats (1998)                                               NaN
# $5 a Day (2008)                                                                NaN
# 'Hellboy': The Seeds of Creation (2004)                                        NaN
# 'Neath the Arizona Skies (1934)                                                NaN
# 'Round Midnight (1986)                                                         NaN
#
# [5 rows x 12272 columns]

# %% [markdown]
# Let's show some movie recommendations for user ID 1, who I've added for validation. User ID 1 likes Star Wars and The Empire Strikes Back, but hated Gone with the Wind.
#
# **use dropna()** to keep movies that have been rated!

# %%
myRatings = userRatings.loc[1].dropna()
myRatings
# Out:
# title
# 2001: A Space Odyssey (1968)                                       3.5
# 28 Days Later (2002)                                               3.5
# 7th Voyage of Sinbad, The (1958)                                   4.0
# Adventures of Baron Munchausen, The (1988)                         4.0
# Alien (1979)                                                       4.0
# Aliens (1986)                                                      4.0
# American Werewolf in London, An (1981)                             4.0
# Apocalypse Now (1979)                                              3.5
# Army of Darkness (1993)                                            4.0
# Austin Powers: The Spy Who Shagged Me (1999)                       3.5
# Beastmaster, The (1982)                                            3.0
# Beetlejuice (1988)                                                 4.0
# Bill & Ted's Bogus Journey (1991)                                  3.5
# Bill & Ted's Excellent Adventure (1989)                            4.0
# Birds, The (1963)                                                  4.0
# Blade Runner (1982)                                                4.0
# Borrowers, The (1997)                                              3.5
# Brotherhood of the Wolf (Pacte des loups, Le) (2001)               4.0
# Bubba Ho-tep (2002)                                                3.5
# Butch Cassidy and the Sundance Kid (1969)                          3.0
# Chitty Chitty Bang Bang (1968)                                     3.5
# Christmas Story, A (1983)                                          3.5
# City of Lost Children, The (Cité des enfants perdus, La) (1995)    3.5
# Clash of the Titans (1981)                                         4.0
# Clerks (1994)                                                      4.0
# Company of Wolves, The (1984)                                      4.0
# Conan the Destroyer (1984)                                         3.0
# Constantine (2005)                                                 4.0
# Contact (1997)                                                     3.5
# Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000)            4.0
#                                                                   ...
# Star Wars: Episode IV - A New Hope (1977)                          4.0
# Star Wars: Episode V - The Empire Strikes Back (1980)              4.5
# Sword and the Sorcerer, The (1982)                                 3.5
# Teenage Mutant Ninja Turtles (1990)                                3.5
# Terminator 2: Judgment Day (1991)                                  3.5
# Terminator, The (1984)                                             4.0
# Thing, The (1982)                                                  4.0
# Time Bandits (1981)                                                4.0
# Time Machine, The (2002)                                           4.0
# Toys (1992)                                                        3.5
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                          3.5
# Underworld (2003)                                                  4.0
# Unforgiven (1992)                                                  4.0
# Untouchables, The (1987)                                           3.5
# Usual Suspects, The (1995)                                         3.5
# Vampire Hunter D: Bloodlust (Banpaia hantâ D) (2000)               3.5
# Van Helsing (2004)                                                 4.0
# Videodrome (1983)                                                  4.0
# Warriors of Virtue (1997)                                          3.0
# Watership Down (1978)                                              4.0
# What's Eating Gilbert Grape (1993)                                 3.5
# Wicker Man, The (1973)                                             4.0
# Wilder Napalm (1993)                                               3.5
# Willow (1988)                                                      4.0
# Witches of Eastwick, The (1987)                                    4.0
# Witches, The (1990)                                                3.5
# Wizard of Oz, The (1939)                                           3.5
# X2: X-Men United (2003)                                            4.0
# Yojimbo (1961)                                                     3.0
# Young Frankenstein (1974)                                          4.0
# Name: 1, Length: 175, dtype: float64

# %% [markdown]
# Next, let's go through each movie I rated one at a time, and build up a list of possible recommendations based on the movies similar to the ones I rated.
#
# For each movie I rated, I'll retrieve the list of similar movies from our correlation matrix. I'll then scale those correlation scores by how well I rated the movie they are similar to, so movies similar to ones I liked count more than movies similar to ones I hated:

# %%
similar_candidates = pd.Series()
for i in range(0, len(myRatings.index)):
    print("Adding similar movies for " + myRatings.index[i] + "...")
    # retrieve similar movies to this one that I rated
    similar_movies = corrMatrix[myRatings.index[i]].dropna()
    # scale its similarity by how well I rated this movie
    similar_movies = similar_movies.map(lambda x: x * myRatings[i])
    # add the score to the list of similar candidates
    similar_candidates = similar_candidates.append(similar_movies)
    
print("Sort recommendations...")
similar_candidates.sort_values(inplace = True, ascending = False)
similar_candidates.head(10)
# Out:
# Adding similar movies for 2001: A Space Odyssey (1968)...
# Adding similar movies for 28 Days Later (2002)...
# Adding similar movies for 7th Voyage of Sinbad, The (1958)...
# Adding similar movies for Adventures of Baron Munchausen, The (1988)...
# Adding similar movies for Alien (1979)...
# Adding similar movies for Aliens (1986)...
# Adding similar movies for American Werewolf in London, An (1981)...
# Adding similar movies for Apocalypse Now (1979)...
# Adding similar movies for Army of Darkness (1993)...
# Adding similar movies for Austin Powers: The Spy Who Shagged Me (1999)...
# Adding similar movies for Beastmaster, The (1982)...
# Adding similar movies for Beetlejuice (1988)...
# Adding similar movies for Bill & Ted's Bogus Journey (1991)...
# Adding similar movies for Bill & Ted's Excellent Adventure (1989)...
# Adding similar movies for Birds, The (1963)...
# Adding similar movies for Blade Runner (1982)...
# Adding similar movies for Borrowers, The (1997)...
# Adding similar movies for Brotherhood of the Wolf (Pacte des loups, Le) (2001)...
# Adding similar movies for Bubba Ho-tep (2002)...
# Adding similar movies for Butch Cassidy and the Sundance Kid (1969)...
# Adding similar movies for Chitty Chitty Bang Bang (1968)...
# Adding similar movies for Christmas Story, A (1983)...
# Adding similar movies for City of Lost Children, The (Cité des enfants perdus, La) (1995)...
# Adding similar movies for Clash of the Titans (1981)...
# Adding similar movies for Clerks (1994)...
# Adding similar movies for Company of Wolves, The (1984)...
# Adding similar movies for Conan the Destroyer (1984)...
# Adding similar movies for Constantine (2005)...
# Adding similar movies for Contact (1997)...
# Adding similar movies for Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000
# Adding similar movies for Teenage Mutant Ninja Turtles (1990)...
# Adding similar movies for Terminator 2: Judgment Day (1991)...
# Adding similar movies for Terminator, The (1984)...
# Adding similar movies for Thing, The (1982)...
# Adding similar movies for Time Bandits (1981)...
# Adding similar movies for Time Machine, The (2002)...
# Adding similar movies for Toys (1992)...
# Adding similar movies for Twelve Monkeys (a.k.a. 12 Monkeys) (1995)...
# Adding similar movies for Underworld (2003)...
# Adding similar movies for Unforgiven (1992)...
# Adding similar movies for Untouchables, The (1987)...
# Adding similar movies for Usual Suspects, The (1995)...
# Adding similar movies for Vampire Hunter D: Bloodlust (Banpaia hantâ D) (2000)...
# Adding similar movies for Van Helsing (2004)...
# Adding similar movies for Videodrome (1983)...
# Adding similar movies for Warriors of Virtue (1997)...
# Adding similar movies for Watership Down (1978)...
# Adding similar movies for What's Eating Gilbert Grape (1993)...
# Adding similar movies for Wicker Man, The (1973)...
# Adding similar movies for Wilder Napalm (1993)...
# Adding similar movies for Willow (1988)...
# Adding similar movies for Witches of Eastwick, The (1987)...
# Adding similar movies for Witches, The (1990)...
# Adding similar movies for Wizard of Oz, The (1939)...
# Adding similar movies for X2: X-Men United (2003)...
# Adding similar movies for Yojimbo (1961)...
# Adding similar movies for Young Frankenstein (1974)...
# Sort recommendations...
# Lord of the Rings: The Two Towers, The (2002)                                     5.000000
# Lord of the Rings: The Fellowship of the Ring, The (2001)                         5.000000
# Lord of the Rings: The Return of the King, The (2003)                             5.000000
# Star Wars: Episode V - The Empire Strikes Back (1980)                             4.500000
# Spider-Man 2 (2004)                                                               4.500000
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)    4.500000
# Lord of the Rings: The Two Towers, The (2002)                                     4.400666
# Lord of the Rings: The Return of the King, The (2003)                             4.400666
# Lord of the Rings: The Return of the King, The (2003)                             4.353071
# Lord of the Rings: The Fellowship of the Ring, The (2001)                         4.353071
# dtype: float64

# %% [markdown]
# Notice some of the same movies came up more than once, because they were similar to more than one movie I rated. Let's use **groupby()** to add together the scores from movies that show up more than once, so they'll count more:

# %%
similar_candidates = similar_candidates.groupby(similar_candidates.index).sum()

# %%
similar_candidates.sort_values(inplace = True, ascending = False)
similar_candidates.head(10)
# Out:
# Aliens (1986)                                                                     104.549547
# Terminator, The (1984)                                                            102.166397
# Toy Story 2 (1999)                                                                100.207342
# Alien (1979)                                                                       98.187615
# Ghostbusters (a.k.a. Ghost Busters) (1984)                                         98.031349
# Men in Black (a.k.a. MIB) (1997)                                                   96.197739
# Star Wars: Episode IV - A New Hope (1977)                                          94.046253
# Toy Story (1995)                                                                   93.177287
# Back to the Future (1985)                                                          93.003814
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)     92.876196
# dtype: float64

# %% [markdown]
# Filter out movies I've already rated, as recommending a movie I've already watched isn't helpful:

# %% [markdown]
# ## Further Enhancements

# %% [markdown]
# + Experiment with different methods rather than Pearson correlation
# + Use a different value for min_periods for the correlation computation
# + How do we filter out movies similar to the ones I've hated? Perhaps penalize movies similar to the ones I've hated (rather than scale it down)!
# + Some users have rated lots of movies which may have a disporportionate effect on the results. Consider removing outliers.
